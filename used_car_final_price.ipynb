# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data set
df_train = pd.read_csv("F:\\used_car_price_dataset\\data.csv")

# %%
df_train
# Out:
#       Unnamed: 0                              Name                   Location  \
# 0            0.0            Maruti Wagon R LXI CNG                     Mumbai
# 1            1.0  Hyundai Creta 1.6 CRDi SX Option                       Pune
# 2            2.0                      Honda Jazz V                    Chennai
# 3            3.0                 Maruti Ertiga VDI                    Chennai
# 4            4.0   Audi A4 New 2.0 TDI Multitronic                 Coimbatore
# ...          ...                               ...                        ...
# 7322         NaN          Hyundai Santro Asta BSIV              99Nm@ 4500rpm
# 7323         NaN          Maruti Wagon R VXI BS IV              90Nm@ 3500rpm
# 7324         NaN             Hyundai Verna CRDi SX  24@ 1,900-2,750(kgm@ rpm)
# 7325         NaN                   Maruti Alto LXi              62Nm@ 3000rpm
# 7326         NaN             Honda Accord VTi-L MT        20@ 4,700(kgm@ rpm)
#
# ...

# %%
df_train.shape
# Out:
# (7327, 14)

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0           1308
# Name                    0
# Location               23
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                24
# Engine                 58
# Power                  58
# Seats                  64
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df=df_train

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7327 entries, 0 to 7326
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   float64
#  1   Name               7327 non-null   object
#  2   Location           7304 non-null   object
#  3   Year               7327 non-null   int64
#  4   Kilometers_Driven  7327 non-null   int64
#  5   Fuel_Type          7327 non-null   object
#  6   Transmission       7327 non-null   object
#  7   Owner_Type         7327 non-null   object
#  8   Mileage            7303 non-null   object
#  9   Engine             7269 non-null   object
#  10  Power              7269 non-null   object
#  11  Seats              7263 non-null   float64
#  12  New_Price          2132 non-null   object
#  13  Price              7327 non-null   float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 801.5+ KB

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().mean()*100
# Out:
# Unnamed: 0           17.851781
# Name                  0.000000
# Location              0.313907
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.327556
# Engine                0.791593
# Power                 0.791593
# Seats                 0.873482
# New_Price            70.902143
# Price                 0.000000
# dtype: float64

# %%
df.drop(['Unnamed: 0', 'Location', 'New_Price', 'Power'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                Name  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R LXI CNG  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 2                      Honda Jazz V  2011              46000    Petrol
# 3                 Maruti Ertiga VDI  2012              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
#
#   Transmission Owner_Type     Mileage   Engine  Seats  Price
# 0       Manual      First  26.6 km/kg   998 CC    5.0   1.75
# 1       Manual      First  19.67 kmpl  1582 CC    5.0  12.50
# 2       Manual      First   18.2 kmpl  1199 CC    5.0   4.50
# 3       Manual      First  20.77 kmpl  1248 CC    7.0   6.00
# 4    Automatic     Second   15.2 kmpl  1968 CC    5.0  17.74

# %%
df.isnull().sum()
# Out:
# Name                  0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage              24
# Engine               58
# Seats                64
# Price                 0
# dtype: int64

# %%
# visualize missing value in heatmap
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull())

# %%
# fill mean value in balcony feature because in 4% missing value
df['Seats']=df['Seats'].fillna(df['Seats'].mean())
df.isnull().sum()
# Out:
# Name                  0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage              24
# Engine               58
# Seats                 0
# Price                 0
# dtype: int64

# %%
df[['Mileage', 'Engine']] = df[['Mileage', 'Engine']].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Name                 0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Seats                0
# Price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7327 entries, 0 to 7326
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7327 non-null   object
#  1   Year               7327 non-null   int64
#  2   Kilometers_Driven  7327 non-null   int64
#  3   Fuel_Type          7327 non-null   object
#  4   Transmission       7327 non-null   object
#  5   Owner_Type         7327 non-null   object
#  6   Mileage            7327 non-null   object
#  7   Engine             7327 non-null   object
#  8   Seats              7327 non-null   float64
#  9   Price              7327 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 572.5+ KB

# %%
# to show the all row and columns
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df.dtypes
# Out:
# Name                  object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Seats                float64
# Price                float64
# dtype: object

# %%
df['Owner_Type'].value_counts()
# Out:
# First                   5803
# Second                  1280
# Third                    191
# Fourth & Above Owner      28
# Second                    11
# Fourth & Above             9
# Test Drive Car             4
# First                      1
# Name: Owner_Type, dtype: int64

# %%
df['Mileage'].value_counts()
# Out:
# 18.9 kmpl      206
# 17.0 kmpl      193
# 18.6 kmpl      141
# 21.1 kmpl      107
# 17.8 kmpl       97
# 20.36 kmpl      94
# 12.8 kmpl       89
# 16.0 kmpl       88
# 18.0 kmpl       86
# 20.0 kmpl       81
# 15.1 kmpl       78
# 12.99 kmpl      77
# 16.8 kmpl       75
# 18.5 kmpl       75
# 13.0 kmpl       73
# 19.7 kmpl       71
# 22.7 kmpl       70
# 0.0 kmpl        69
# 16.1 kmpl       66
# 16.47 kmpl      60
# 24.3 kmpl       60
# 22.32 kmpl      59
# 25.8 kmpl       59
# 22.9 kmpl       58
# 23.1 kmpl       57
# 24.0 kmpl       57
# 19.3 kmpl       55
# 19.0 kmpl       55
# 28.4 kmpl       54
# 23.0 kmpl       51
# 17.5 kmpl       50
# 23.4 kmpl       50
# 22.0 kmpl       49
# 12.05 kmpl      49
# 15.0 kmpl       48
# 20.77 kmpl      48
# 19.1 kmpl       48
# 21.4 kmpl       48
# 19.81 kmpl      48
# 19.01 kmpl      47
# 20.51 kmpl      45
# 11.5 kmpl       45
# 13.5 kmpl       45
# 19.4 kmpl       43
# 17.01 kmpl      43
# 19.67 kmpl      43
# 14.0 kmpl       43
# ...

# %%
#Mileage
df['Mileage'] = df['Mileage'].str.replace('kmpl', '')
df['Mileage'] = df['Mileage'].str.replace('km/kg', '')
df['Mileage'] = df['Mileage'].astype('float64')

# %%
#Engine
df['Engine'] = df['Engine'].str.replace('CC', '')
df['Engine'] = df['Engine'].astype('int64')

# %%
df.isnull().sum()
# Out:
# Name                 0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Seats                0
# Price                0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                  object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                 int64
# Seats                float64
# Price                float64
# dtype: object

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3936
# Petrol      3310
# CNG           66
# LPG           13
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Manual       5395
# Automatic    1932
# Name: Transmission, dtype: int64

# %%
Owner_Type_mapping={'First':0,'Second':1,'Third':2,'Fourth & Above Owner':3,'Fourth & Above':4,'Test Drive Car':5}
Fuel_Type_mapping = {'Diesel':0, 'Petrol':1, 'CNG':2,'LPG':3,'Electric':4}
Transmission_mapping = {'Manual':0, 'Automatic':1}

# %%
df['Owner_Type']= df['Owner_Type'].map(Owner_Type_mapping)
df['Fuel_Type'] = df['Fuel_Type'].map(Fuel_Type_mapping)
df['Transmission'] = df['Transmission'].map(Transmission_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7327 entries, 0 to 7326
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7327 non-null   object
#  1   Year               7327 non-null   int64
#  2   Kilometers_Driven  7327 non-null   int64
#  3   Fuel_Type          7327 non-null   int64
#  4   Transmission       7327 non-null   int64
#  5   Owner_Type         7315 non-null   float64
#  6   Mileage            7327 non-null   float64
#  7   Engine             7327 non-null   int64
#  8   Seats              7327 non-null   float64
#  9   Price              7327 non-null   float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 572.5+ KB

# %%
df['Owner_Type'].value_counts()
# Out:
# 0.0    5803
# 1.0    1280
# 2.0     191
# 3.0      28
# 4.0       9
# 5.0       4
# Name: Owner_Type, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                  0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type           12
# Mileage               0
# Engine                0
# Seats                 0
# Price                 0
# dtype: int64

# %%
df1=df.dropna()

# %%
cols_for_class_distribution = ['Fuel_Type','Owner_Type', 'Transmission', 'Seats']

# %%
for col in df_train[cols_for_class_distribution]:
    sns.countplot(df1[col])
    plt.xlabel(col)
    plt.show()

# %%
#drop 3rd person owner 
df1.drop(df1[df1['Owner_Type'] > 3].index, inplace = True)
# Out:
# F:\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1.shape
# Out:
# (7302, 10)

# %%
# 8 thi uper ni seat na hoy car ma
df1.drop(df1[df1['Seats'] > 8].index, inplace = True)

# %%
df1.shape
# Out:
# (7281, 10)

# %%
#drop not lpg and electric 
df1.drop(df1[df1['Fuel_Type'] > 2].index, inplace = True)

# %%
df1.isnull().sum()
# Out:
# Name                 0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Seats                0
# Price                0
# dtype: int64

# %%
df1.dtypes
# Out:
# Name                  object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int64
# Transmission           int64
# Owner_Type           float64
# Mileage              float64
# Engine                 int64
# Seats                float64
# Price                float64
# dtype: object

# %%
for col in df_train[cols_for_class_distribution]:
    sns.countplot(df1[col])
    plt.xlabel(col)
    plt.show()

# %%
df1.head(2)
# Out:
#                                Name  Year  Kilometers_Driven  Fuel_Type  \
# 0            Maruti Wagon R LXI CNG  2010              72000          2
# 1  Hyundai Creta 1.6 CRDi SX Option  2015              41000          0
#
#    Transmission  Owner_Type  Mileage  Engine  Seats  Price
# 0             0         0.0    26.60     998    5.0   1.75
# 1             0         0.0    19.67    1582    5.0  12.50

# %%
"""Name feature"""
name_value_count = df1['Name'].value_counts()
name_value_count
# Out:
# Maruti Swift Dzire VDI                                         56
# Maruti Swift VDI                                               55
# Mahindra XUV500 W8 2WD                                         52
# Maruti Ritz VDi                                                38
# Maruti Swift VDI BSIV                                          37
# Maruti Alto LXi                                                36
# Honda City 1.5 S MT                                            35
# Maruti Ertiga VDI                                              33
# Maruti Wagon R LXI                                             32
# Toyota Fortuner 3.0 Diesel                                     31
# Hyundai i10 Sportz                                             31
# Hyundai Grand i10 Sportz                                       31
# Maruti Alto 800 LXI                                            30
# Honda Amaze S i-Dtech                                          30
# ...

# %%
name_gert_3 = name_value_count[name_value_count>=2].index
name_gert_3
# Out:
# Index(['Maruti Swift Dzire VDI', 'Maruti Swift VDI', 'Mahindra XUV500 W8 2WD',
#        'Maruti Ritz VDi', 'Maruti Swift VDI BSIV', 'Maruti Alto LXi',
#        'Honda City 1.5 S MT', 'Maruti Ertiga VDI', 'Maruti Wagon R LXI',
#        'Toyota Fortuner 3.0 Diesel',
#        ...
#        'Mahindra Quanto C8', 'Mitsubishi Outlander 2.4',
#        'Hyundai Verna 1.4 EX', 'Honda Jazz 1.2 S i VTEC',
#        'Ford Fiesta 1.4 SXi TDCi', 'Chevrolet Enjoy TCDi LS 8 Seater',
#        'Mahindra XUV500 AT W6 2WD', 'Honda Mobilio V i DTEC',
#        'Jeep Compass 2.0 Sport', 'Tata Nano XT'],
#       dtype='object', length=1193)

# %%
# for train data set categorical data to one hot encoing
for cat_var in name_gert_3:
  df1[cat_var]=np.where(df1['Name']==cat_var, 1,0)
# Out:
# <ipython-input-46-9d4b24d67a95>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[cat_var]=np.where(df1['Name']==cat_var, 1,0)

# %%
df1.shape
# Out:
# (7266, 1203)

# %%
df1=df1.drop('Name',axis =1)

# %%
df1.shape
# Out:
# (7266, 1202)

# %%
df1.head()
# Out:
#    Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  Mileage  \
# 0  2010              72000          2             0         0.0    26.60
# 1  2015              41000          0             0         0.0    19.67
# 2  2011              46000          1             0         0.0    18.20
# 3  2012              87000          0             0         0.0    20.77
# 4  2013              40670          0             1         1.0    15.20
#
#    Engine  Seats  Price  Maruti Swift Dzire VDI  Maruti Swift VDI  \
# 0     998    5.0   1.75                       0                 0
# 1    1582    5.0  12.50                       0                 0
# 2    1199    5.0   4.50                       0                 0
# 3    1248    7.0   6.00                       0                 0
# 4    1968    5.0  17.74                       0                 0
#
#    Mahindra XUV500 W8 2WD  Maruti Ritz VDi  Maruti Swift VDI BSIV  \
# ...

# %%
df1.to_csv(r'F:\\used_car_price_dataset\\car_preprocessing.csv',index=False)

# %% [markdown]
# # Split dataset for train and test

# %%
X = df1.drop('Price',axis=1)
y = df1['Price']
print('shape of x = ', X.shape)
print('shape of y= ',y.shape)
# Out:
# shape of x =  (7266, 1201)
# shape of y=  (7266,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2,random_state=51)
print('shape of X_train = ',X_train.shape)
print('shape of y_train = ',y_train.shape)
print('shape of X_test = ',X_test.shape)
print('shape of y_test = ',y_test.shape)
# Out:
# shape of X_train =  (5812, 1201)
# shape of y_train =  (5812,)
# shape of X_test =  (1454, 1201)
# shape of y_test =  (1454,)

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train= sc.transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Model Building and training

# %% [markdown]
# # Xgboost

# %%
from sklearn.metrics import mean_squared_error
def rmse(y_test, y_pred):
  return np.sqrt(mean_squared_error(y_test, y_pred))

# %%
import xgboost
xgb_reg = xgboost.XGBRegressor()
xgb_reg.fit(X_train,y_train)
xgb_reg_score=xgb_reg.score(X_test,y_test) 
xgb_reg_rmse = rmse(y_test, xgb_reg.predict(X_test))
xgb_reg_score, xgb_reg_rmse
# Out:
# (0.8927482331848517, 3.3089202171738474)

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
rfr_score=rfr.score(X_test,y_test) 
rfr_rmse = rmse(y_test, rfr.predict(X_test))
rfr_score, rfr_rmse
# Out:
# (0.8775866855335084, 3.5350730831621346)

# %% [markdown]
# # ExtraTree Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
modelextra = ExtraTreesRegressor(n_estimators=100,verbose=1,n_jobs=4,warm_start=True,max_features=150, min_samples_split=2)
modelextra.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    9.7s finished
# ExtraTreesRegressor(max_features=150, n_jobs=4, verbose=1, warm_start=True)

# %%
model_score=modelextra.score(X_test,y_test) 
model_rmse = rmse(y_test, modelextra.predict(X_test))
model_score, model_rmse
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# (0.904063158749179, 3.1295131136680285)

# %%
print(pd.DataFrame([
              {'Model': 'Random Forest','Score':rfr_score, "RMSE":rfr_rmse},
              {'Model': 'ExtraTree Rgressor','Score':model_score, "RMSE":model_rmse},
              {'Model': 'XGBoost','Score':xgb_reg_score, "RMSE":xgb_reg_rmse}],
             columns=['Model','Score','RMSE']))
# Out:
#                 Model     Score      RMSE
# 0       Random Forest  0.877587  3.535073
# 1  ExtraTree Rgressor  0.904063  3.129513
# 2             XGBoost  0.892748  3.308920

# %% [markdown]
# # Test model

# %%
list(X.columns)
# Out:
# ['Year',
#  'Kilometers_Driven',
#  'Fuel_Type',
#  'Transmission',
#  'Owner_Type',
#  'Mileage',
#  'Engine',
#  'Seats',
#  'Maruti Swift Dzire VDI',
#  'Maruti Swift VDI',
#  'Mahindra XUV500 W8 2WD',
#  'Maruti Ritz VDi',
#  'Maruti Swift VDI BSIV',
#  'Maruti Alto LXi',
#  'Honda City 1.5 S MT',
#  'Maruti Ertiga VDI',
#  'Maruti Wagon R LXI',
#  'Toyota Fortuner 3.0 Diesel',
#  'Hyundai i10 Sportz',
#  'Hyundai Grand i10 Sportz',
#  'Maruti Alto 800 LXI',
#  'Honda Amaze S i-Dtech',
#  'Maruti Wagon R VXI',
#  'Maruti Swift Dzire VXI',
#  'Hyundai Verna 1.6 SX',
#  'Hyundai EON Era Plus',
#  'Honda Brio S MT',
#  'Honda City 1.5 V MT',
#  'Maruti Ertiga ZDI',
#  'Maruti Swift Dzire VDi',
#  'Volkswagen Vento Diesel Highline',
#  'Mahindra XUV500 W6 2WD',
#  'Ford Figo Diesel Titanium',
#  'Maruti Alto K10 VXI',
#  'Renault KWID RXT',
#  'Toyota Fortuner 4x2 AT',
#  'Maruti Wagon R VXI BS IV',
#  'Skoda Superb Elegance 1.8 TSI AT',
#  'Renault Duster 110PS Diesel RxZ',
# ...

# %%
import numpy as np

# %%
 
# it help to get predicted value of hosue  by providing features value 
def predict_price(model,Year,Kilometers_Driven,Fuel_Type,Transmission,Owner_Type,Mileage,Engine,Seats,Name):
 
  x =np.zeros(len(X.columns)) # create zero numpy array
 
  # adding feature's value accorind to their column index
  x[0]=Year
  x[1]=Kilometers_Driven
  x[2]=Fuel_Type
  x[3]=Transmission
  x[4]=Owner_Type
  x[5]=Mileage
  x[6]=Engine
  x[7]=Seats
 
 
  if Name in X.columns:
    name_index = np.where(X.columns==Name)[0][0]
    x[name_index] =1
 
 
  #print(x)
     # feature scaling
  x = sc.transform([x])[0] 
  #print(x)
 
  return model.predict([x])[0] # return the predicted value by train xgboost Regrssion model

predict_price(model=modelextra,Year=2011,Kilometers_Driven=46000,Fuel_Type=1,Transmission=0,Owner_Type=0,Mileage=18.2,Engine=1199,Seats=5,Name="Honda Jazz V")
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.0s finished
# 4.5

# %% [markdown]
# # save model

# %%
from joblib import dump

dump(modelextra, 'filename.joblib')
# Out:
# ['filename.joblib']
